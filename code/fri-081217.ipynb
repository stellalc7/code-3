# %%
import pandas as pd
import numpy as np
from __future__ import division
import calendar
import time
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import matplotlib.dates as md
# %matplotlib inline
import seaborn as sns
from scipy import stats
from dateutil.parser import parse
from pandas.tslib import Timestamp
colorz=sns.color_palette("husl", 8)
sns.palplot(sns.color_palette("husl", 8))
import matplotlib.dates as mdates

# %%
data=pd.read_csv('/Users/stella/Desktop/Piaq_export2.csv', delimiter='\t', skiprows=2)
data=data[['CO2','sootLDSA']].reset_index().dropna()
data.columns=['time','CO2','LDSA']
data=data[data['LDSA']>0]
data['time']=[parse(s) for s in data['time']]

# %%
#plt_data = range(5,9)
#plt.subplots_adjust(bottom=0.2)
#plt.xticks( rotation=25 )

ax=plt.gca()
ax.set_xticks(data['time'])

xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
ax.xaxis.set_major_formatter(xfmt)
plt.plot(data['time'],data['LDSA'], "o-")
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-65eb1860fb16> in <module>()
#       4
#       5 ax=plt.gca()
# ----> 6 ax.set_xticks(data['time'])
#       7
#       8 xfmt = md.DateFormatter('%Y-%m-%d %H:%M:%S')
#
# /Users/stella/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in set_xticks(self, ticks, minor)
#    2843         ACCEPTS: sequence of floats
#    2844         """
# -> 2845         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2846         self.stale = True
#    2847         return ret
#
# /Users/stella/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in set_ticks(self, ticks, minor)
#    1598             xleft, xright = self.get_view_interval()
#    1599             if xright > xleft:
# -> 1600                 self.set_view_interval(min(ticks), max(ticks))
#    1601             else:
# ...

# %%
plt.plot(data['time'],data['LDSA'])

# %%
plt.plot(data['time'],data['CO2'])
plt.ylim([1010,1020])
# Out:
# (1010, 1020)
